# %%
from __future__ import print_function  # Python 2 and 3
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
# %matplotlib inline
pd.set_option('display.max_rows', 137)
pd.set_option('display.max_columns', 80)

# %%
og = pd.read_csv('accepted_2007_to_2018Q4.csv')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
forest_df = pd.read_csv('pool_forest_df.csv', index_col=0)

# %%
forest_df
# Out:
#          loan_amnt  term  int_rate  installment  sub_grade  emp_length  \
# 1794613     5000.0     0     17.76       180.17          0          10
# 1251081     4675.0     0     20.99       176.11          8          10
# 1870096    35000.0     1     22.95       985.67         10          10
# 1349744    12700.0     0     18.25       460.73          2           8
# 1230387     4000.0     0     23.43       155.74         10          10
# ...            ...   ...       ...          ...        ...         ...
# 1761494     2500.0     0     23.70        97.69         10           9
# 1204917     1200.0     0     23.43        46.73         10          10
# 1861220     2500.0     0     19.05        91.71          3           8
# 1855743     4800.0     0     18.49       174.72          1           5
# 1898392    20000.0     0     18.49       727.98          1           1
#
#          home_ownership  annual_inc  purpose  addr_state    dti  delinq_2yrs  \
# ...

# %%
ind_forest = list(forest_df.index)

# %%
og[og.index.isin(ind_forest)]
# Out:
#                id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 1118702  35873425        NaN    12000.0      12000.0          12000.0
# 1121064  37297282        NaN    20000.0      20000.0          20000.0
# 1121554  36900316        NaN     6000.0       6000.0           6000.0
# 1127895  35948810        NaN    13200.0      13200.0          13200.0
# 1131168  34313404        NaN     7500.0       7500.0           7500.0
# ...           ...        ...        ...          ...              ...
# 1934362   1129853        NaN    12000.0      12000.0          12000.0
# 1934611   1148202        NaN    35000.0      35000.0          35000.0
# 1934754   1146331        NaN    23000.0      23000.0          22750.0
# 1936384   1120237        NaN     4800.0       4800.0           4800.0
# 1938351   1090297        NaN     1500.0       1500.0           1500.0
#
#                term  int_rate  installment grade sub_grade  \
# 1118702   60 months     12.39       269.31     C        C1
# ...

# %%
boos_reg_df = pd.read_csv('pool_boost_reg_df.csv', index_col=0)

# %%
ind_boost_reg = list(boos_reg_df.index)
og[og.index.isin(ind_boost_reg)]
# Out:
#                id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 1122335  35226271        NaN     8400.0       8400.0      8400.000000
# 1125034  36410707        NaN     5000.0       5000.0      5000.000000
# 1125875  36230262        NaN    28000.0      28000.0     28000.000000
# 1127809  35979048        NaN    35000.0      35000.0     35000.000000
# 1127895  35948810        NaN    13200.0      13200.0     13200.000000
# ...           ...        ...        ...          ...              ...
# 1931580   1197331        NaN    12000.0      12000.0     12000.000000
# 1933228   1172066        NaN    19600.0      19600.0     19594.845457
# 1935163   1134904        NaN    12000.0      12000.0     12000.000000
# 1936010   1125205        NaN    25000.0      25000.0     24917.316129
# 1938871   1076138        NaN     2300.0       2300.0      2300.000000
#
#                term  int_rate  installment grade sub_grade  \
# 1122335   36 months      7.49       261.26     A        A4
# ...

# %%
boos_class_df = pd.read_csv('pool_boost_class_df.csv', index_col=0)

# %%
ind_boost_class = list(boos_class_df.index)
og[og.index.isin(ind_boost_class)]
# Out:
#                id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 1117949  36251522        NaN     6000.0       6000.0           6000.0
# 1119243  36300666        NaN    25000.0      25000.0          24975.0
# 1120105  37317416        NaN     7000.0       7000.0           7000.0
# 1120231  36231355        NaN    21075.0      21075.0          21075.0
# 1122575  35103789        NaN     8000.0       8000.0           8000.0
# ...           ...        ...        ...          ...              ...
# 1934230   1132448        NaN    16000.0      16000.0          16000.0
# 1934556   1149079        NaN    12000.0      12000.0          12000.0
# 1935801   1128908        NaN    28000.0      28000.0          27925.0
# 1936847   1112481        NaN     2750.0       2750.0           2750.0
# 1938606   1082652        NaN    10600.0      10600.0          10550.0
#
#                term  int_rate  installment grade sub_grade  \
# 1117949   36 months     10.49       194.99     B        B3
# ...
