# %%
from __future__ import print_function  # Python 2 and 3
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
import seaborn as sns

# %%
xgb_class = pd.read_csv('pool_boost_class_df.csv', index_col = 'Unnamed: 0')
xgb_reg = pd.read_csv('pool_boost_reg_df.csv', index_col = 'Unnamed: 0')
forest_reg = pd.read_csv('pool_forest_df.csv', index_col = 'Unnamed: 0')

# %%
#xgb_class = xgb_class.drop(columns = ['loan_status','prob_paid_back','emp_title'])
#xgb_reg = xgb_reg.drop(columns = ['prediction'])
#forest_reg = forest_reg.drop(columns = ['test_prediction'])

# %%
data = pd.read_csv('accepted_2007_to_2018Q4.csv')
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
xgb_class['model'] = 'XGBoost Classifier'
xgb_reg['model'] = 'XGBoost Regressor'
forest_reg['model'] = 'Random Forest Regressor'
data_cagr['model'] = 'Population'

# %%
pools = pd.concat([xgb_class[['cagr','id','model']],xgb_reg[['cagr','id','model']],forest_reg[['cagr','id','model']],data_cagr[['cagr','id','model']]],axis = 0)

# %%
pools = pools.merge(data[['id','loan_amnt','annual_inc','installment','term','int_rate','grade','sub_grade','emp_length','home_ownership','loan_status','issue_d','addr_state','dti','fico_range_high','revol_util','total_pymnt','chargeoff_within_12_mths', 'total_acc']])

# %%
pools.head()
# Out:
#        cagr        id               model  loan_amnt  annual_inc  installment  \
# 0  0.009320  37840324  XGBoost Classifier     1125.0     23000.0        40.19
# 1  0.009320  37840324          Population     1125.0     23000.0        40.19
# 2  0.002807  36039529  XGBoost Classifier     1300.0     16000.0        45.70
# 3  0.002807  36039529          Population     1300.0     16000.0        45.70
# 4  0.074406  37307656  XGBoost Classifier    25000.0     65000.0       533.96
#
#          term  int_rate grade sub_grade  ... home_ownership loan_status  \
# 0   36 months     17.14     D        D4  ...           RENT  Fully Paid
# 1   36 months     17.14     D        D4  ...           RENT  Fully Paid
# 2   36 months     15.99     D        D2  ...       MORTGAGE  Fully Paid
# 3   36 months     15.99     D        D2  ...       MORTGAGE  Fully Paid
# 4   60 months      6.00     D        D5  ...           RENT  Fully Paid
#
#     issue_d addr_state    dti  fico_range_high  revol_util  total_pymnt  \
# 0  Dec-2014         AR  26.98            719.0        78.3   1156.75000
# 1  Dec-2014         AR  26.98            719.0        78.3   1156.75000
# 2  Dec-2014         CA  13.95            674.0        15.8   1310.98000
# 3  Dec-2014         CA  13.95            674.0        15.8   1310.98000
# 4  Dec-2014         OH  31.46            719.0        80.6  35791.74216
#
#    chargeoff_within_12_mths  total_acc
# 0                       0.0       12.0
# 1                       0.0       12.0
# 2                       0.0       46.0
# 3                       0.0       46.0
# 4                       0.0       32.0
#
# [5 rows x 21 columns]

# %%
for i in ['int_rate','loan_amnt','cagr','annual_inc','fico_range_high','revol_util','dti', 'total_acc']:
    plt.figure()
    chart = sns.boxplot(x = 'model', y = i, data = pools[pools['model']!= 'Population'],palette = sns.color_palette("Blues", n_colors=7))
    chart.set_xticklabels(chart.get_xticklabels(), rotation=45)

# %%
for i in ['int_rate','loan_amnt','cagr','annual_inc','fico_range_high','revol_util','dti', 'total_acc']:
    plt.figure()
    chart = sns.boxplot(x = 'model', y = i, data = pools,palette = sns.color_palette("Blues", n_colors=7))
    chart.set_xticklabels(chart.get_xticklabels(), rotation=45)

# %%
for i in ['int_rate','loan_amnt','cagr','annual_inc','fico_range_high','revol_util','dti', 'total_acc','exp_payment_delta']:
    for x in ['XGBoost Classifier', 'Population', 'XGBoost Regressor', 'Random Forest Regressor']:
        plt.figure()
        chart = sns.distplot(pools.loc[pools['model'] == x,i]).set_title(x)
        #chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
for i in ['grade','term','loan_status']:
    for x in ['XGBoost Classifier', 'Population', 'XGBoost Regressor', 'Random Forest Regressor']:
        plt.figure()
        sns.countplot(data = pools[pools['model'] == x], x = i).set_title(x)

# %%
# population boxplots
sns.boxplot(data = pools[pools['model'] == 'Population'], x = 'term',  y = 'cagr')

# %%
sns.barplot(data = pools[pools['model'] == 'Population'].groupby(['loan_status','term'])['term'].count().reset_index(name = 'count'), x = 'term', y = 'count', hue = 'loan_status')

# %%
sns.barplot(data = pools[pools['model'] == 'Population'].groupby(['loan_status','term'])['term'].count().reset_index(name = 'count'), x = 'term', y = 'count', hue = 'loan_status', palette = sns.color_palette("Blues"))
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
x = sns.barplot(data = pools[pools['model'] == 'Population'].groupby(['loan_status','term'])['term'].count().reset_index(name = 'count'), x = 'term', y = 'count', hue = 'loan_status', palette = sns.color_palette("Blues")).set_title('Charge Off versus Fully Paid Count')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
x.set(xlabel = 'Term', ylabel = 'Count')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-29ce33e92359> in <module>
#       1 x = sns.barplot(data = pools[pools['model'] == 'Population'].groupby(['loan_status','term'])['term'].count().reset_index(name = 'count'), x = 'term', y = 'count', hue = 'loan_status', palette = sns.color_palette("Blues")).set_title('Charge Off versus Fully Paid Count')
#       2 plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# ----> 3 x.set(xlabel = 'Term', ylabel = 'Count')
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in set(self, **kwargs)
#    1069             sorted(kwargs.items(), reverse=True,
#    1070                    key=lambda x: (self._prop_order.get(x[0], 0), x[0])))
# -> 1071         return self.update(props)
#    1072
#    1073     def findobj(self, match=None, include_self=True):
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/text.py in update(self, kwargs)
#     175         sentinel = object()  # bbox can be None, so use another sentinel.
#     176         bbox = kwargs.pop("bbox", sentinel)
# --> 177         super().update(kwargs)
#     178         if bbox is not sentinel:
#     179             self.set_bbox(bbox)
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in update(self, props)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# --> 974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#     976         if len(ret):
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in <listcomp>(.0)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# --> 974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#     976         if len(ret):
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#     968                 if not callable(func):
#     969                     raise AttributeError('{!r} object has no property {!r}'
# --> 970                                          .format(type(self).__name__, k))
#     971                 return func(v)
#     972
#
# AttributeError: 'Text' object has no property 'ylabel'

# %%
pools[pools['model'] == 'Population'].groupby(['loan_status','term'])['term'].count()
# Out:
# loan_status  term
# Charged Off   36 months     47584
#               60 months     65192
# Fully Paid    36 months    118390
#               60 months     95491
# Name: term, dtype: int64

# %%
# how similar are the pools of loans
l = pools[pools['model'] != 'Population']
l = l[['model','id']].merge(l[['model','id']], on= 'id')
pd.crosstab(l.model_x,l.model_y)
# Out:
# model_y                  Random Forest Regressor  XGBoost Classifier  \
# model_x
# Random Forest Regressor                      767                  17
# XGBoost Classifier                            17                 594
# XGBoost Regressor                             52                  42
#
# model_y                  XGBoost Regressor
# model_x
# Random Forest Regressor                 52
# XGBoost Classifier                      42
# XGBoost Regressor                      697

# %%
sns.boxplot(data = pools[pools['model'] == 'Population'], x = 'loan_status',  y = 'cagr')

# %%
# percent of loans paid back early
pools[pools['model'] == 'Population']
# Out:
#             cagr        id       model  loan_amnt  installment        term  \
# 1       0.009320  37840324  Population     1125.0        40.19   36 months
# 3       0.002807  36039529  Population     1300.0        45.70   36 months
# 5       0.074406  37307656  Population    25000.0       533.96   60 months
# 7       0.023247  36611144  Population    35000.0       899.09   60 months
# 9       0.083913  36280959  Population     1000.0        35.40   36 months
# ...          ...       ...         ...        ...          ...         ...
# 328710  0.005987  90805411  Population    32500.0       825.11   60 months
# 328711  0.067929  90141265  Population    10400.0       284.23   60 months
# 328712 -0.114773  90726974  Population    16000.0       414.97   60 months
# 328713  0.011100  90855576  Population    28000.0       868.26   60 months
# 328714 -0.499833  90826977  Population     2000.0        74.32   36 months
#
#         int_rate grade sub_grade emp_length home_ownership  loan_status  \
# 1          17.14     D        D4    3 years           RENT   Fully Paid
# 3          15.99     D        D2    2 years       MORTGAGE   Fully Paid
# 5           6.00     D        D5  10+ years           RENT   Fully Paid
# 7          18.54     E        E1  10+ years       MORTGAGE   Fully Paid
# 9          16.49     D        D3    2 years           RENT   Fully Paid
# ...          ...   ...       ...        ...            ...          ...
# 328710     17.99     D        D2  10+ years           RENT   Fully Paid
# 328711     21.49     D        D5  10+ years       MORTGAGE   Fully Paid
# 328712     18.99     D        D3    4 years       MORTGAGE  Charged Off
# 328713     27.79     F        F5    8 years           RENT   Fully Paid
# 328714     19.99     D        D4        NaN            OWN  Charged Off
#
#          issue_d addr_state    dti  fico_range_high  revol_util   total_pymnt  \
# 1       Dec-2014         AR  26.98            719.0        78.3   1156.750000
# 3       Dec-2014         CA  13.95            674.0        15.8   1310.980000
# 5       Dec-2014         OH  31.46            719.0        80.6  35791.742160
# 7       Dec-2014         CA  15.18            724.0        35.9  39261.780000
# 9       Dec-2014         CA  26.66            664.0        97.2   1273.453487
# ...          ...        ...    ...              ...         ...           ...
# 328710  Oct-2016         NJ  27.99            709.0        56.9  33484.615180
# 328711  Oct-2016         IL  15.70            664.0        72.4  14445.908792
# 328712  Oct-2016         WI   9.22            669.0        53.1   8697.490000
# 328713  Oct-2016         CA  15.10            714.0        25.4  29588.883874
# 328714  Oct-2016         MD  20.14            664.0        74.4    250.250000
#
#         chargeoff_within_12_mths  annual_inc  total_acc
# 1                            0.0     23000.0       12.0
# 3                            0.0     16000.0       46.0
# 5                            0.0     65000.0       32.0
# 7                            0.0    400000.0       32.0
# 9                            0.0     28000.0       14.0
# ...                          ...         ...        ...
# 328710                       0.0     65000.0       18.0
# 328711                       0.0     58000.0       21.0
# 328712                       0.0     69000.0       13.0
# 328713                       0.0     75000.0       32.0
# 328714                       0.0     77000.0       54.0
#
# [326657 rows x 21 columns]

# %%
# create expected payment columns
pools['term_int'] = pools['term'].apply(lambda x: int(x.strip()[:2]))

pools['expected_payments'] = pools['installment'] * pools['term_int']

pools['exp_payment_delta'] = pools['total_pymnt'] - pools['expected_payments']

# %%
sns.boxplot(data = pools[pools['model'] == 'Population'], x = 'loan_status', y = 'exp_payment_delta')

# %%
x=sns.boxplot(data = pools[pools['model'] == 'Population'], x = 'loan_status', y = 'exp_payment_delta', hue = 'term', palette = sns.color_palette("Blues"))
x.set_title('Expected Payments Delta By Term')
x.set(xlabel = 'Term', ylabel = 'Expected Payments Delta')
# Out:
# [Text(0, 0.5, 'Expected Payments Delta'), Text(0.5, 0, 'Term')]

# %%
x = sns.barplot(data = pools[pools['model'] == 'Population'].groupby(['loan_status','term'])['term'].count().reset_index(name = 'count'), x = 'term', y = 'count', hue = 'loan_status', palette = sns.color_palette("Blues")).set_title('Charge Off versus Fully Paid Count')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('Term')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
sns.boxplot(data = pools.loc[(pools['loan_status'] == 'Fully Paid') & (pools['model'] != 'Population')], x = 'model', y = 'exp_payment_delta')

# %%
temp = pools.groupby(['model','term'])['term'].count()#.reset_index(name = 'count')

# %%
temp = temp.groupby(level = 0).apply(lambda x: 100*x/float(x.sum())).reset_index(name = 'count')

# %%
x = sns.barplot(data = temp, x = 'model', y = 'count', hue = 'term', palette = sns.color_palette("Blues"))
x.set_xticklabels(x.get_xticklabels(),rotation=90)
x.set_title('Term Percentage By Model')
x.set(xlabel = 'Model', ylabel = 'Term Percentage')
# Out:
# [Text(0, 0.5, 'Term Percentage'), Text(0.5, 0, 'Model')]

# %%
temp
# Out:
#                      model        term       count
# 0               Population   36 months   50.809871
# 1               Population   60 months   49.190129
# 2  Random Forest Regressor   36 months   94.915254
# 3  Random Forest Regressor   60 months    5.084746
# 4       XGBoost Classifier   36 months   94.107744
# 5       XGBoost Classifier   60 months    5.892256
# 6        XGBoost Regressor   36 months  100.000000
